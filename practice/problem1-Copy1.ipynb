# %% [raw]
# # Problem 1
# %matplotlib inline
# import csv
# import matplotlib.pyplot as plt
# from scipy import stats
# import numpy as np
#
# # Counting state visits
# states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA",
#           "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD",
#           "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ",
#           "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC",
#           "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
#
# visits = []
#
# with open("visits.csv", "rt") as f:
#     reader = csv.reader(f)
#     for row in reader:
#         visits.append(row[1])
#
# num_visits = {}
# for state in states:
#     num_visits[state] = visits.count(state)
#
# print(num_visits)
#
# state_repub = {}
# # Party affiliaition in 2014 per state
# with open("partyaffiliation.csv", "rt") as f:
#     reader = csv.reader(f)
#     c = 0
#     for row in reader:
#         state_repub[states[c]] = float(row[1].strip('%'))/100
#         c+=1
# print(state_repub)
#
# # Proportions for each states
# results = []
# with open("presidential_results.csv", "rt") as f:
#     reader = csv.reader(f)
#     currState = "AK"
#     currVotesTrump = 0.0
#     currVotesTotal = 0.0
#
#     for row in reader:
#         #print(currState + " " + row[8])
#         #print(currState == row[8])
#         if (currState != row[8]):
#             print(currState)
#             print(currVotesTrump/currVotesTotal)
#             results.append([currState, currVotesTrump/currVotesTotal])
#
#             currState = row[8]
#             currVotesTrump = 0
#             currVotesTotal = 0
#
#         currVotesTrump = currVotesTrump + float(row[2])
#         currVotesTotal = currVotesTotal + float(row[3])

# %%
# Creating logistic model
X = []
Y = []
for states in results: # states is an array [CA, 0.5]
    X.append(num_visits[states[0]])
    Y.append(states[1]-state_repub[states[0]])

    print(states[0] + " " + str(num_visits[states[0]]) + " " + str(states[1]-state_repub[states[0]]))

slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
plt.plot(X, Y, 'o', label="original data")
plt.plot(X, intercept + slope*np.array(X), 'r', label="fitted line")
plt.legend()
plt.show()
# Out:
# AK 0 0.1388700180057424
# AL 0 0.10888413576400335
# AR 0 0.15148730623345347
# AZ 4 0.09503056510294206
# CA 0 0.02759788785925621
# CO 10 0.0335931884789904
# CT 1 0.09160992447377397
# DC 0 -0.24877932865216645
# DE 0 0.309226108915488
# FL 25 0.1206399978693371
# GA 1 0.10336149518905774
# HI 0 0.020390602227015664
# IA 7 0.10781279166234575
# ID 0 0.10165691951150413
# IL 0 0.06413260939139753
# IN 1 0.15171323303315282
# KS 0 0.11186331608177885
# KY 0 0.18580935148874894
# LA 0 0.17094688102120054
# MA 0 0.06515661771463743
# MD 0 0.04305347290388567
# ME 4 0.09153799474074575
# MI 6 0.1358598406108893
# MN 1 0.06360347880471978
# MO 0 0.16142234256231675
# MS 1 0.14337453471105005
# MT 0 0.07686256912075506
# NC 18 0.09537156405127073
# ND 0 0.14140511858692817
# NE 0 0.13302393879136787
# NH 8 0.12267798778762445
# NJ 0 0.11783883231430142
# NM 1 0.03335092520114874
# NV 5 0.08531928156083313
# NY 0 0.09475225920446195
# OH 15 0.10052176411327235
# OK 0 0.20327182410603034
# ...
